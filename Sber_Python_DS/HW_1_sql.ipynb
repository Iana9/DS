# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect(':memory:')

# %%
table_names = [
    'Categories',   # категории товаров
    'Customers',    # заказчики
    'Employees',    # сотрудники
    'OrderDetails', # детали заказов
    'Orders',       # заказы
    'Products',     # товары
    'Shippers',     # перевозчики
    'Suppliers',    # поставщики
]

# %%
for table in table_names:
    data = pd.read_csv(f'{table}.csv', sep = ';')
    data.to_sql(table, con, index=False, if_exists='replace')

# %%
pd.read_sql(
    '''
    SELECT * FROM Categories
    ''',
    con,
)
# Out:
#    CategoryID    CategoryName  \
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           5  Grains/Cereals
# 5           6    Meat/Poultry
# 6           7         Produce
# 7           8         Seafood
#
#                                          Description
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 3                                            Cheeses
# 4                Breads, crackers, pasta, and cereal
# 5                                     Prepared meats
# 6                          Dried fruit and bean curd
# 7                                   Seaweed and fish

# %%
tasks = 0

# %% [markdown]
# ### Все задания нужно выполнить только с помощью sql

# %% [markdown]
# 1. Выберите заказчиков из Германии, Франции и Мадрида, выведите их название, страну и адрес.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT CustomerName, Country, Address 
    FROM 
        Customers
    WHERE Country IN ('Germany', 'France', 'Spain')
    ''',
    con,
)
# Out:
#                             CustomerName  Country  \
# 0                    Alfreds Futterkiste  Germany
# 1                Blauer See Delikatessen  Germany
# 2                   Blondel père et fils   France
# 3              Bólido Comidas preparadas    Spain
# 4                               Bon app'   France
# 5              Drachenblut Delikatessend  Germany
# 6                        Du monde entier   France
# 7   FISSA Fabrica Inter. Salchichas S.A.    Spain
# 8                      Folies gourmandes   France
# 9                         Frankenversand  Germany
# 10                   France restauration   France
# 11                Galería del gastrónomo    Spain
# 12                   Godos Cocina Típica    Spain
# 13                       Königlich Essen  Germany
# 14                  La corne d'abondance   France
# 15                      La maison d'Asie   France
# 16                   Lehmanns Marktstand  Germany
# 17                Morgenstern Gesundkost  Germany
# 18                    Ottilies Käseladen  Germany
# 19                     Paris spécialités   France
# 20                            QUICK-Stop  Germany
# 21                      Romero y tomillo    Spain
# 22                  Spécialités du monde   France
# 23                    Toms Spezialitäten  Germany
# 24                  Victuailles en stock   France
# 25             Vins et alcools Chevalier   France
# 26                     Die Wandernde Kuh  Germany
#
#                          Address
# 0                  Obere Str. 57
# 1                 Forsterstr. 57
# 2               24, place Kléber
# 3                 C/ Araquil, 67
# 4           12, rue des Bouchers
# 5                   Walserweg 21
# 6   67, rue des Cinquante Otages
# 7             C/ Moralzarzal, 86
# 8       184, chaussée de Tournai
# 9              Berliner Platz 43
# 10                54, rue Royale
# 11        Rambla de Cataluña, 23
# 12                 C/ Romero, 33
# 13                 Maubelstr. 90
# 14        67, avenue de l'Europe
# 15         1 rue Alsace-Lorraine
# 16                  Magazinweg 7
# 17                   Heerstr. 22
# 18            Mehrheimerstr. 369
# 19       265, boulevard Charonne
# 20              Taucherstraße 10
# 21                   Gran Vía, 1
# 22             25, rue Lauriston
# 23                 Luisenstr. 48
# 24            2, rue du Commerce
# 25            59 rue de l'Abbaye
# 26             Adenauerallee 900

# %% [markdown]
# 2. Выберите топ 3 страны по количеству заказчиков, выведите их названия и количество записей.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT Country, count(*) as cnt 
    FROM 
        Customers
    GROUP BY Country
    ORDER BY count(*) desc
    LIMIT 3
    ''',
    con,
)
# Out:
#    Country  cnt
# 0      USA   13
# 1  Germany   11
# 2   France   11

# %% [markdown]
# 3. Выберите перевозчика, который отправил 10-й по времени заказ, выведите его название, и дату отправления.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT ShipperName, OrderDate 
    FROM (
        SELECT *
        , row_number() over (
        order by substr(OrderDate, 7) || "-" || substr(OrderDate,4,2)  || "-" || substr(OrderDate, 1,2) asc
        ) as rn 
        FROM 
            Orders o
        INNER JOIN 
            Shippers s 
        ON 
            o.ShipperID=s.ShipperID)
    WHERE rn = 10
    ''',
    con,
)
# Out:
#         ShipperName   OrderDate
# 0  Federal Shipping  16.07.1996

# %% [markdown]
# 4. Выберите самый дорогой заказ, выведите список товаров с их ценами.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT p.ProductID, p.ProductName, p.Price
    FROM OrderDetails od
    INNER JOIN 
        Products p
    ON
        p.ProductID=od.ProductID
    WHERE OrderID = (
        SELECT OrderID
        FROM Products p
        INNER JOIN OrderDetails o ON p.ProductID=o.ProductID
        GROUP BY OrderID
        ORDER BY sum(Price*Quantity) desc
        LIMIT 1)
    ''',
    con,
)
# Out:
#    ProductID             ProductName  Price
# 0         20  Sir Rodney's Marmalade     81
# 1         38           Côte de Blaye  263.5
# 2         60       Camembert Pierrot     34
# 3         72  Mozzarella di Giovanni   34.8

# %% [markdown]
# 5. Какой товар больше всего заказывали по количеству единиц товара, выведите его название и количество единиц в каждом из заказов.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT p.ProductName, o.Quantity, o.OrderID
    FROM 
        Products p
    INNER JOIN 
        OrderDetails o 
    ON 
        p.ProductID=o.ProductID
    INNER JOIN
        (SELECT ProductID
        FROM 
            OrderDetails
        GROUP BY ProductID
        ORDER BY sum(Quantity) desc
        LIMIT 1) f
    ON
        p.ProductID=f.ProductID
    ''',
    con,
)
# Out:
#           ProductName  Quantity  OrderID
# 0   Gorgonzola Telino        20    10253
# 1   Gorgonzola Telino        40    10272
# 2   Gorgonzola Telino        15    10273
# 3   Gorgonzola Telino         4    10325
# 4   Gorgonzola Telino        25    10335
# 5   Gorgonzola Telino        56    10342
# 6   Gorgonzola Telino        30    10356
# 7   Gorgonzola Telino        70    10359
# 8   Gorgonzola Telino        20    10363
# 9   Gorgonzola Telino        30    10374
# 10  Gorgonzola Telino        42    10376
# 11  Gorgonzola Telino        60    10390
# 12  Gorgonzola Telino        32    10393
# 13  Gorgonzola Telino        14    10423

# %% [markdown]
# 6. Выведите топ 5 поставщиков по количеству заказов, выведите их названия, страну, контактное лицо и телефон.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT s.SupplierName, s.Country, s.ContactName, s.Phone
    FROM 
        OrderDetails o
    INNER JOIN
        Products p
    ON
        o.ProductID=p.ProductID
    LEFT JOIN
        Suppliers s
    ON
        p.SupplierID=s.SupplierID
    GROUP BY p.SupplierID
    ORDER BY count(distinct OrderID) desc
    LIMIT 5
    ''',
    con,
)
# Out:
#                         SupplierName    Country   ContactName           Phone
# 0  Plutzer Lebensmittelgroßmärkte AG    Germany   Martin Bein    (069) 992755
# 1                      Pavlova, Ltd.  Australia   Ian Devling   (03) 444-2343
# 2           Specialty Biscuits, Ltd.         UK  Peter Wilson  (161) 555-4448
# 3                    Norske Meierier     Norway  Beate Vileid     (0)2-953010
# 4            Formaggi Fortini s.r.l.      Italy    Elio Rossi    (0544) 60323

# %% [markdown]
# 7. Какую категорию товаров заказывали больше всего по стоимости в Бразилии, выведите страну, название категории и сумму.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT cu.Country, c.CategoryName, sum(Quantity*Price) as sum
    FROM 
        OrderDetails od
    INNER JOIN
        Products p
    ON
        od.ProductID=p.ProductID
    INNER JOIN
        Categories c
    ON
        p.CategoryID=c.CategoryID
    INNER JOIN
        Orders o
    ON
        od.OrderID=o.OrderID
    INNER JOIN
        Customers cu
    ON
        o.CustomerID=cu.CustomerID and cu.Country='Brazil'
    GROUP BY c.CategoryID
    ORDER BY sum(Quantity*Price) desc
    LIMIT 1
    ''',
    con,
)
# Out:
#   Country CategoryName      sum
# 0  Brazil    Beverages  13636.0

# %% [markdown]
# 8. Какая разница в стоимости между самым дорогим и самым дешевым заказом из США.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT max(sum) - min(sum) as diff 
        FROM(
        SELECT cu.Country
        , od.OrderID
        , sum(Quantity*Price) as sum
        FROM 
            OrderDetails od
        INNER JOIN
            Products p
        ON
            od.ProductID=p.ProductID
        INNER JOIN
            Categories c
        ON
            p.CategoryID=c.CategoryID
        INNER JOIN
            Orders o
        ON
            od.OrderID=o.OrderID
        INNER JOIN
            Customers cu
        ON
            o.CustomerID=cu.CustomerID and cu.Country='USA'
        GROUP BY od.OrderID)
    ''',
    con,
)
# Out:
#       diff
# 0  7698.45

# %%
pd.read_sql(
    '''
        SELECT *
        FROM 
            OrderDetails od
                INNER JOIN
            Products p
        ON
            od.ProductID=p.ProductID
        WHERE OrderID=10349
    ''',
    con,
)
# Out:
#    OrderDetailID  OrderID  ProductID  Quantity  ProductID ProductName  \
# 0            272    10349         54        24         54   Tourtière
#
#    SupplierID  CategoryID     Unit    Price
# 0          25           6  16 pies  июль.45

# %% [markdown]
# 9. Выведите количество заказов у каждого их трех самых молодых сотрудников, а также имя и фамилию во второй колонке.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT 
    count(distinct OrderID) as cnt_orders,
    FirstName ||' '|| LastName as Emp,
    DATE('now') -
    substr(BirthDate, 7) || "-" || substr(BirthDate,4,2)  || "-" || substr(BirthDate, 1,2) as Age,
    substr(BirthDate, 7) || "-" || substr(BirthDate,4,2)  || "-" || substr(BirthDate, 1,2) as NewBirth
    FROM Employees e
    INNER JOIN
        Orders o
    ON
        e.EmployeeID=o.EmployeeID
    GROUP BY e.EmployeeID
    ORDER BY substr(BirthDate, 7) || "-" || substr(BirthDate,4,2)  || "-" || substr(BirthDate, 1,2) desc
    LIMIT 3
    ''',
    con,
)
# Out:
#    cnt_orders              Emp  Age    NewBirth
# 0           6   Anne Dodsworth   54  1969-07-02
# 1          29    Nancy Davolio   55  1968-12-08
# 2          31  Janet Leverling   60  1963-08-30

# %% [markdown]
# 10. Сколько банок крабового мяса всего было заказано.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT sum(Quantity) as crab_meat
    FROM 
        Products p
    INNER JOIN
        OrderDetails od
    ON
        p.ProductID=od.ProductID
    WHERE lower(p.ProductName) like '%crab%'
    ''',
    con,
)
# Out:
#    crab_meat
# 0        256

# %%
if tasks==10:
    print('Выполнены все задания 🙂')
else:
    print('Выполнены не все задания! 🙀')
# Out:
# Выполнены все задания 🙂
