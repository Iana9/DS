# %% [markdown]
# # Практика

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import math
from tqdm.auto import tqdm
import statsmodels.stats.weightstats as ssw
# %matplotlib inline

# %% [markdown]
# ## ЦПТ для различных распределений
# Возьмите то непрерывное распределение, которое вам больше всего понравится из списка доступных в модуле [scipy.stats](https://docs.scipy.org/doc/scipy/reference/stats.html).

# %% [markdown]
# ### Сгенерируйте примеры из распределения

# %%
# ваш код тут
# например вот такое распределение https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.cosine.html#scipy.stats.cosine
a = 1.99
gamma_rv = sts.gamma(a)
sample = gamma_rv.rvs(100)
sample
# Out:
# array([0.56010152, 1.31726819, 0.6758973 , 1.36266789, 0.64966958,
#        2.89726288, 5.94613799, 2.17570349, 1.1220792 , 3.53761382,
#        2.54398421, 2.99129538, 1.63366373, 1.11595642, 2.32735501,
#        1.22084809, 0.76915612, 3.87449218, 0.33197433, 1.91169712,
#        2.248636  , 1.0392894 , 1.10550385, 1.7437184 , 3.83551749,
#        1.84578578, 4.53342466, 1.58424334, 0.31589118, 0.57585918,
#        1.38934574, 2.25443584, 2.39575284, 1.7530022 , 2.31682059,
#        0.50194149, 0.57967377, 2.41980173, 2.20718282, 1.47936604,
#        2.32740803, 0.54155202, 0.31089938, 1.40190066, 1.17461442,
#        2.88726757, 1.13164782, 0.51643456, 0.44543217, 1.21048729,
#        3.21931939, 2.6212625 , 0.96426467, 2.73894587, 2.65937178,
#        1.28878217, 0.92136352, 2.17937816, 3.1340962 , 1.11685108,
#        0.71072387, 0.83825337, 3.6819121 , 7.20662282, 7.68687755,
#        2.91159641, 2.59602576, 0.97685819, 1.85359637, 0.934322  ,
# ...

# %%
sample.dtype
# Out:
# dtype('float64')

# %%
real_mean = gamma_rv.mean() # настоящее среднее случайной величины

# %%
real_var = gamma_rv.var() # настоящая дисперсия случайной величины

# %% [markdown]
# ### Постройте гистограмму выборки и теоретическую плотность распределения

# %%
plt.rcParams['figure.dpi'] = 1000
plt.rcParams['figure.figsize'] = (8, 2)

# %%
# ваш код тут
plt.hist(sample, density=True)
x = np.linspace(0,7,100)
pdf = gamma_rv.pdf(x)
plt.plot(x, pdf, label='теоретическая плотность', alpha=0.5)
plt.legend();

# %%
sample_mean = sample.mean() # выборочное среднее
print(sample_mean)
sample_var = sample.var() # выборочная дисперсия
print(sample_var)
# Out:
# 2.0311025871736046
# 2.144137330139651

# %%
print(real_mean)
print(real_var)
# Out:
# 1.99
# 1.99

# %% [markdown]
# ### Оценим распределение выборочного среднего для разных объёмов выборок
# Для этого постройте на одном полотне гистограмму выборочных средних и теоретическое распределение выборочных средних по ЦПТ для разных объёмов выборок.
#
# Для теоретического распределение используйте настоящие значения мат ожидания и дисперсии (не приближенные на основе выборки).

# %%
# ваш код тут
N = 30
NN = 100000
# сгенерируем много выборочных средних
means = []
for i in tqdm(range(NN)):
    means.append(np.mean(gamma_rv.rvs(N)))
plt.hist(means, density=True, bins='auto')

norm_rv = sts.norm(loc=real_mean, scale=np.sqrt(real_var) / np.sqrt(N))
x = np.linspace(1, 4, 100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf, label='Теоретическая плотность', alpha=0.5);
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %% [markdown]
# Как вы считаете, для выбранного распределения апроксимация распределения выборочного среднего работает хорошо или плохо?
# **Ваш ответ:**

# %% [markdown]
# Да, при увеличении забираемого в сэмпл, выборка средних приближается к нормальному распределению.

# %% [markdown]
# ## Доверительный интервал на основе ЦПТ
# Возьмите данные для оттока телеком компании, и постройте доверительные интервалы для среднего значения total day calls, используя центральную предельную теорему в разбиении по колонке churn (ушел/не ушел).
#
# Для оценки дисперсии используйте несмещенную оценку (параметр ddof=1).
#
# Сделайте оценку с использованием явной формулы для z интервала, а затем с помощью функций
# `from statsmodels.stats.weightstats import _zconfint_generic`. Сравните результаты.
#
#
# Ссылка на данные: https://drive.google.com/file/d/1X_drKqoarnU2Sz2har7uSCsgyhh8Xtz8/view?usp=sharing

# %%
# либо загружаем из альтернативного хранилища
url ="https://raw.githubusercontent.com/piton1/DS/Lesson_5/telecom_churn.csv"
df=pd.read_csv(url)
display(df)
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
variance = df.groupby(['churn'])['total day calls'].var(ddof=1)

# %%
df['total day calls'].isnull().sum()
# Out:
# 0

# %%
plt.hist(df[df.churn == True]['total day calls'], density=True, bins='auto')
plt.hist(df[df.churn == False]['total day calls'], density=True, bins='auto')
plt.legend(['ушёл', 'не ушёл'])
plt.show()

# %%
N = 100
NN = 50000
# сгенерируем много выборочных средних
means_True = []
means_False = []
for i in tqdm(range(NN)):
    means_True.append(np.mean(df[df.churn == True]['total day calls'].sample(N)))
    means_False.append(np.mean(df[df.churn == False]['total day calls'].sample(N)))
plt.hist(means_True, density=True, bins='auto')
plt.hist(means_False, density=True, bins='auto')
plt.title('ЦПТ')
plt.legend(['ушёл', 'не ушёл'])
plt.show()
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]

# %%
#data = uniform_rv.rvs(N)
print("Ушёл - Доверительный интервал для среднего по цпт, если нам известна дисперсия: [{}, {}] ".format(
    np.mean(means_True) - 1.96 * np.sqrt(variance.loc[True]) / np.sqrt(N-1), np.mean(means_True) + 1.96 * np.sqrt(variance.loc[True]) / np.sqrt(N-1) 
))

print("Не Ушёл - Доверительный интервал для среднего по цпт, если нам известна дисперсия: [{}, {}] ".format(
    np.mean(means_False) - 1.96 * np.sqrt(variance.loc[False]) / np.sqrt(N-1), np.mean(means_False) + 1.96 * np.sqrt(variance.loc[False]) / np.sqrt(N-1) 
))


print("Ушёл - Доверительный интервал для среднего по цпт методом _zconfint_generic: {} ".format(
    ssw._zconfint_generic(np.mean(means_True),  np.std(means_True, ddof=1), alpha=0.95, alternative='two-sided')
))

print("Не Ушёл - Доверительный интервал для среднего по цпт методом _zconfint_generic: {} ".format(
    ssw._zconfint_generic(np.mean(means_False),  np.std(means_False, ddof=1), alpha=0.95, alternative='two-sided')
))
# Out:
# Ушёл - Доверительный интервал для среднего по цпт, если нам известна дисперсия: [97.08988276162222, 105.59276843837779]
# Не Ушёл - Доверительный интервал для среднего по цпт, если нам известна дисперсия: [96.39313294160034, 104.19429025839962]
# Ушёл - Доверительный интервал для среднего по цпт методом _zconfint_generic: (101.22106139305498, 101.46158980694503)
# Не Ушёл - Доверительный интервал для среднего по цпт методом _zconfint_generic: (100.17191809969874, 100.41550510030122)
